# %%
Q1. Explain why we have to use the Exception class while creating a Custom Exception.
Answer--The Exception class serves as a base class for all exceptions in Python,
and when you create a custom exception by inheriting from it.
Creating custom exceptions by subclassing the built-in
Exception class is a common practice in many programming languages, including Python. 
1. Customization
2.Clarity
3.Hierarchical structure
4.Selective Catching
5.Consistency
6.Documentation and Communication


Q2. Write a python program to print Python Exception Hierarchy.
Answer--def print_exception_hierarchy(exception_class, depth=0):
    indent = '  ' * depth
    print(f"{indent}{exception_class.__name__}")
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, depth + 1)

print_exception_hierarchy(BaseException)


Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
Answer--The ArithmeticError class in Python is the base class for exceptions that occur
during arithmetic operations. It encompasses various specific arithmetic-related exceptions.
Two of the exceptions derived from ArithmeticError are ZeroDivisionError and OverflowError. 
1.Zero division
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print(f"Error: {e}")

2.Overflowerror
import sys

try:
    big_number = sys.maxsize + 1  # This will cause an OverflowError
except OverflowError as e:
    print(f"Error: {e}")

Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.   
Answer--The LookupError class in Python is the base class for exceptions that 
occur when you try to access a sequence (like a list or tuple) or a mapping (like a dictionary) 
using invalid or non-existent keys or indices. It provides a common base for exceptions that
involve lookup operations.
Two common exceptions derived from LookupError are KeyError and IndexError.

The LookupError class in Python is the base class for exceptions that occur when you try to access a sequence (like a list or tuple) or a mapping (like a dictionary) using invalid or non-existent keys or indices. It provides a common base for exceptions that involve lookup operations. Two common exceptions derived from LookupError are KeyError and IndexError.

A--KeyError:
This exception is raised when you
try to access a dictionary with a key that doesn't exist in the dictionary.
my_dict = {"a": 1, "b": 2, "c": 3}

try:
    value = my_dict["x"]
except KeyError as e:
    print(f"Error: {e}")

B--IndexError:
This exception occurs when you try to access a sequence (like a list or a string)
using an invalid index, i.e., an index that is out of the valid range for the sequence.
my_list = [1, 2, 3]

try:
    value = my_list[5]
except IndexError as e:
    print(f"Error: {e}")

    
Q5. Explain ImportError. What is ModuleNotFoundError? 
Answer--ImportError is an exception class in Python that is raised when there's an issue
importing a module or a specific symbol (like a function or class) from a module.
This error occurs when the Python interpreter is unable to locate the module you are trying to
import or when there are issues within the module itself that prevent it from being imported.
try:
    import non_existent_module
except ImportError as e:
    print(f"ImportError: {e}")
    
    
ModuleNotFoundError is actually a subclass of ImportError that was introduced in Python 3.6. 
It provides a more specific error message when a module cannot be found during the import process.
try:
    import non_existent_module
except ModuleNotFoundError as e:
    print(f"ModuleNotFoundError: {e}")
Q6. List down some best practices for exception handling in python.
Answer--Exception handling is a crucial aspect of writing robust and maintainable Python code.
1-Specific exception Catching
2-Use multiple Except block
3-Avoid Bare 'except'
4-Use 'finally'
5-Handle Exceptions Locally
6-Don't Suppress Errors
7-Logging
8-Custom Exception classes
9-Use context managers 
10-Avoid infinite Except block
11-use 'try '-' except '-'else'
12-Rethrowing
13-Documentation
